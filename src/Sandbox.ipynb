# %%
from bayesian_funcs import *
import igraph

# %%
ibd1, ibd2 = generate_ibd_network('bn'), generate_ibd_network("pc")
# Out:
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'Duo_Inflammation': 'N', 'Gastric_Inflammation': 'N', 'LeftColon_Inflammation': 'N', 'TI_Inflammation': 'N', 'PGA': 'N', 'Hematocrit': 'N', 'ESR': 'N', 'CRP': 'N', 'Albumin': 'N', 'Vitamin D': 'N'}
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'Duo_Inflammation': 'N', 'Gastric_Inflammation': 'N', 'LeftColon_Inflammation': 'N', 'TI_Inflammation': 'N', 'PGA': 'N', 'Hematocrit': 'N', 'ESR': 'N', 'CRP': 'N', 'Albumin': 'N', 'Vitamin D': 'N'}
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'Duo_Inflammation': 'N', 'Gastric_Inflammation': 'N', 'LeftColon_Inflammation': 'N', 'TI_Inflammation': 'N', 'PGA': 'N', 'Hematocrit': 'N', 'ESR': 'N', 'CRP': 'N', 'Albumin': 'N', 'Vitamin D': 'N'}
#   0%|          | 0/1000000 [00:00<?, ?it/s]
# ...

# %%
plot_ibd_network(ibd1,cohort='full')
plot_ibd_network(ibd1,cohort='cd')
plot_ibd_network(ibd2,cohort='full')
plot_ibd_network(ibd2,cohort='cd')

# %%
plot_centrality_comparison(ibd2,ibd1,analtype="betweenness")

# %%
plot_centrality_comparison(ibd2,ibd1,analtype="degree")
