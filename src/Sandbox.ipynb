# %%
from bayesian_funcs import *
import igraph

# %%
ibd_bic, ibd_pc, ibd_bdeu = generate_ibd_network('bn',bn_score='bic'), generate_ibd_network("pc"), generate_ibd_network('bn',bn_score='bdeu')
# Out:
# ...
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
panelled_plots(ibd_pc, ibd_bic, ibd_bdeu, stratify_by="graph", cohort="full")

# %%
panelled_plots(ibd_pc, ibd_bic, ibd_bdeu, stratify_by="graph", cohort="cd")

# %%
panelled_plots(ibd_pc, ibd_bic, ibd_bdeu, stratify_by="diagnosis", graph_type="pc")

# %%
panelled_plots(ibd_pc, ibd_bic, ibd_bdeu, stratify_by="diagnosis", graph_type="bic")

# %%
panelled_plots(ibd_pc, ibd_bic, ibd_bdeu, stratify_by="diagnosis", graph_type="bdeu")

# %%
plot_centrality_comparison(
        ibd_pc, ibd_bic, ibd_bdeu, analtype="betweenness"
        )

# %%
plot_centrality_comparison(
        ibd_pc, ibd_bic, ibd_bdeu, analtype="degree"
        )

# %%
# %%skip true
#
# replicates = 100
#
# stability_full = compare_hamming_distance(
#     pc_ntwrk=ibd_pc,
#     bic_ntwrk=ibd_bic,
#     bdeu_ntwrk=ibd_bdeu,
#     cohort="full",
#     n_boot=replicates,
#     random_state=42
# )
#
# stability = compare_hamming_distance(
#     pc_ntwrk=ibd_pc,
#     bic_ntwrk=ibd_bic,
#     bdeu_ntwrk=ibd_bdeu,
#     cohort="cd",
#     n_boot=replicates,
#     random_state=42
# )
# Out:
# UsageError: Cell magic `%%skip` not found.
